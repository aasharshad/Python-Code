# %%
import pandas as pd

# %%
#csv1 = "ASDM_DIDs_pivot_201701-201713_combined_csv_row0__Buf1Pt4MplPre1_D92B.csv"
#csv2 = "ASDM_DIDs_pivot_201701-201713_combined_csv_row0__Buf1Pt5MplPre2_D92C.csv"

# %%
#df1 = pd.read_csv(csv1, skiprows = 1, header=None,  sep = ";")
#####df1 = df1.T
####df1.to_csv(r'C:\Users\APUJAR1\adityapujar\aditya1.csv', index = False)
###df2 = pd.read_csv(csv2, skiprows = 1, header=None,  sep = ";")
##df2 = df2.T
#df2.to_csv(r'C:\Users\APUJAR1\adityapujar\aditya2.csv', index = False)

# %%
#df1

# %%
#df2

# %%
#adi1 = pd.read_csv("aditya1.csv")
#adi1

# %%
#adi2 = pd.read_csv("aditya2.csv")

# %%
#adi2

# %%
#to remove columns, use df1.drop(["column name 1", "column name 2"], axis = 1, inplace = True)

# %%
#adi1.insert(0, "Age", ["True"], True)
#adi1

# %%
#df2 = df2.drop(df2.index[[0]])
#df2.shape

# %%
#from glob import glob             for ConCatination!

# %%
#files = sorted(glob("datafiles/adityaCopy*.csv"))                   for ConCatination!
#files

# %%
#pd.concat((pd.read_csv(file).assign(filename = file) for file in files), ignore_index = True)       for ConCatination!

# %%
#concatenated1 = pd.concat([adi1, adi2], axis = 1)
#concatenated1

# %%
################# READING DRO FILE ###########################

# %%
dro = pd.read_csv("DRO_events_ASDM_DIDs_pivot_201927-201939.csv", sep = ";")

# %%
dro.head(5)
# Out:
#   DateAndTimeOfEvent VehicleSystem             EventType   HostSpeed  \
# 0   2020-02-27 19:05   City Safety    Auto-brake - Short   23.625000
# 1   2020-02-18 17:38   City Safety  Auto-brake - Limited   63.225000
# 2   2020-02-18 16:24   City Safety  Auto-brake - Limited   26.929688
# 3   2020-02-16 20:31   City Safety  Auto-brake - Limited   64.743750
# 4   2020-02-15 00:10   City Safety    Auto-brake - Short  166.162500
#
#    SpeedLimit_RSI ObjectType                                   MapLocation  \
# 0              30      Truck  https://www.google.se/maps?q=57.6915,11.9523
# 1              80        Car  https://www.google.se/maps?q=57.3421,13.9197
# 2              40        Car  https://www.google.se/maps?q=58.4067,13.8604
# 3              70        Car  https://www.google.se/maps?q=57.7217,12.0047
# 4              80        Car   https://www.google.se/maps?q=57.704,11.8564
#
#                                            ReadOutID  BufferNr RequestingNode  \
# ...

# %%
rid = dro["ReadOutID"]

# %%
classification = dro["Classification"]
BufNum = dro["BufferNr"]

# %%
concatenated2 = pd.concat([rid, classification, BufNum], axis = 1)
concatenated2
# Out:
#                                              ReadOutID  Classification  \
# 0    ASDM_DIDs_pivot_201927-201939_combined.csv (ro...            True
# 1    ASDM_DIDs_pivot_201927-201939_combined.csv (ro...           False
# 2    ASDM_DIDs_pivot_201927-201939_combined.csv (ro...            True
# 3    ASDM_DIDs_pivot_201927-201939_combined.csv (ro...           False
# 4    ASDM_DIDs_pivot_201927-201939_combined.csv (ro...           False
# ..                                                 ...             ...
# 332  ASDM_DIDs_pivot_201927-201939_combined.csv (ro...           False
# 333  ASDM_DIDs_pivot_201927-201939_combined.csv (ro...            True
# 334  ASDM_DIDs_pivot_201927-201939_combined.csv (ro...           False
# 335  ASDM_DIDs_pivot_201927-201939_combined.csv (ro...            True
# 336  ASDM_DIDs_pivot_201927-201939_combined.csv (ro...            True
#
#      BufferNr
# 0           1
# 1           1
# 2           2
# 3           2
# 4           1
# ..        ...
# ...

# %%
rid.head(5)

# %%
a = 'ASDM_DIDs_pivot_201927-201939_combined.csv (row5699)' 
start1 = a.find('pivot_') + 6
end1 = a.find('_combined')
b = a[start1:end1]
print(b)
start2 = a.find('row') + 3
end2 = a.find(')', start2)
c = a[start2:end2]
print(c)
# Out:
# 201927-201939
# 5699

# %%
pwd

# %%
path = 'C:\\Users\\APUJAR1\\adityapujar\\logs_201927to39'

# %%
csv = "ASDM_DIDs_pivot_201927-201939\\ASDM_DIDs_pivot_201927-201939_combined_csv_row0\\ASDM_DIDs_pivot_201927-201939_combined_csv_row0__Buf2Pt4MplPre1_D97C.csv"

# %%
df1 = pd.read_csv(csv, skiprows = 1, header=None,  sep = ";")

# %%
df1.head(5)
# Out:
#                                                   0           1           2   \
# 0  ALgtStdFromWhlSpdSafe_ALgtStdFromWhlSpdSafe()-...    1.373047    0.881836
# 1         AccTgtFrstClstLane_AccTgtFrstClstLane()->A    0.000000    0.000000
# 2        AccTgtFrstClstLane_AccTgtFrstClstLane()->Ag    0.000000    0.000000
# 3   AccTgtFrstClstLane_AccTgtFrstClstLane()->PosnLat    0.000000    0.000000
# 4   AccTgtFrstClstLane_AccTgtFrstClstLane()->PosnLgt  255.000000  255.000000
#
#           3           4           5          6          7          8   \
# 0    0.78418    0.686523    0.587891   0.195312   0.000000   0.000000
# 1    0.00000    0.000000    0.000000   1.090820   0.951660   0.794434
# 2    0.00000    0.000000    0.000000   0.035614   0.091370   0.120972
# 3    0.00000    0.000000    0.000000   0.127808   0.064087   0.174072
# 4  255.00000  255.000000  255.000000  13.250000  13.335938  13.523438
#
#           9   ...         11         12         13         14         15  \
# ...

# %%
import os 
#path = r"ASDM_DIDs_pivot_201927-201939\\ASDM_DIDs_pivot_201927-201939_combined_csv_row0.csv"
path = r"C:\\Users\\APUJAR1\\adityapujar\\logs_201927to39\\ASDM_DIDs_pivot_201927-201939"
l = os.listdir(path)

# %%
print(l)
# Out:
# ['ASDM_DIDs_pivot_201927-201939_combined_csv_row0', 'ASDM_DIDs_pivot_201927-201939_combined_csv_row1', 'ASDM_DIDs_pivot_201927-201939_combined_csv_row10', 'ASDM_DIDs_pivot_201927-201939_combined_csv_row100', 'ASDM_DIDs_pivot_201927-201939_combined_csv_row1000', 'ASDM_DIDs_pivot_201927-201939_combined_csv_row1001', 'ASDM_DIDs_pivot_201927-201939_combined_csv_row1002', 'ASDM_DIDs_pivot_201927-201939_combined_csv_row1003', 'ASDM_DIDs_pivot_201927-201939_combined_csv_row1004', 'ASDM_DIDs_pivot_201927-201939_combined_csv_row1005', 'ASDM_DIDs_pivot_201927-201939_combined_csv_row1006', 'ASDM_DIDs_pivot_201927-201939_combined_csv_row1007', 'ASDM_DIDs_pivot_201927-201939_combined_csv_row1008', 'ASDM_DIDs_pivot_201927-201939_combined_csv_row1009', 'ASDM_DIDs_pivot_201927-201939_combined_csv_row101', 'ASDM_DIDs_pivot_201927-201939_combined_csv_row1010', 'ASDM_DIDs_pivot_201927-201939_combined_csv_row1011', 'ASDM_DIDs_pivot_201927-201939_combined_csv_row1012', 'ASDM_DIDs_pivot_201927-201939_comb
# ...

# %%
len(l)
# Out:
# 1088

# %%
m = l[0:5]
m
# Out:
# ['ASDM_DIDs_pivot_201927-201939_combined_csv_row0',
#  'ASDM_DIDs_pivot_201927-201939_combined_csv_row1',
#  'ASDM_DIDs_pivot_201927-201939_combined_csv_row10',
#  'ASDM_DIDs_pivot_201927-201939_combined_csv_row100',
#  'ASDM_DIDs_pivot_201927-201939_combined_csv_row1000']

# %%
for i in (m):
    n = os.listdir()
    print(i)
# Out:
# ASDM_DIDs_pivot_201927-201939_combined_csv_row0
# ASDM_DIDs_pivot_201927-201939_combined_csv_row1
# ASDM_DIDs_pivot_201927-201939_combined_csv_row10
# ASDM_DIDs_pivot_201927-201939_combined_csv_row100
# ASDM_DIDs_pivot_201927-201939_combined_csv_row1000

# %%
#for root, dirs, files in os.walk(path):
#    print(files)

# %%
j = 0
list1=[]
for root, dirs, files in os.walk(path):
    j = j+1
    list1.append(files)    
print(list1)
# Out:
# [[], ['ASDM_DIDs_pivot_201927-201939_combined_csv_row0__Buf1Pt1Sng_D928.csv', 'ASDM_DIDs_pivot_201927-201939_combined_csv_row0__Buf1Pt2MplPost1_D929.csv', 'ASDM_DIDs_pivot_201927-201939_combined_csv_row0__Buf1Pt3MplPost2_D92A.csv', 'ASDM_DIDs_pivot_201927-201939_combined_csv_row0__Buf1Pt4MplPre1_D92B.csv', 'ASDM_DIDs_pivot_201927-201939_combined_csv_row0__Buf1Pt5MplPre2_D92C.csv', 'ASDM_DIDs_pivot_201927-201939_combined_csv_row0__Buf2Pt1Sng_D979.csv', 'ASDM_DIDs_pivot_201927-201939_combined_csv_row0__Buf2Pt2MplPost1_D97A.csv', 'ASDM_DIDs_pivot_201927-201939_combined_csv_row0__Buf2Pt3MplPost2_D97B.csv', 'ASDM_DIDs_pivot_201927-201939_combined_csv_row0__Buf2Pt4MplPre1_D97C.csv', 'ASDM_DIDs_pivot_201927-201939_combined_csv_row0__Buf2Pt5MplPre2_D97D.csv', 'ASDM_DIDs_pivot_201927-201939_combined_csv_row0__MetaData.csv', 'ASDM_DIDs_pivot_201927-201939_combined_csv_row0__Statistics_D926.csv', 'ASDM_DIDs_pivot_201927-201939_combined_csv_row0__Vehicle_GlobalData.csv'], ['ASDM_DIDs_pivot_20192
# ...

# %%
j
# Out:
# 1089

# %%
len(list1)
# Out:
# 1089

# %%
list2 = list1[2]
for i in list2:
    print(i)
# Out:
# ASDM_DIDs_pivot_201927-201939_combined_csv_row1__Buf1Pt1Sng_D928.csv
# ASDM_DIDs_pivot_201927-201939_combined_csv_row1__Buf1Pt2MplPost1_D929.csv
# ASDM_DIDs_pivot_201927-201939_combined_csv_row1__Buf1Pt3MplPost2_D92A.csv
# ASDM_DIDs_pivot_201927-201939_combined_csv_row1__Buf1Pt4MplPre1_D92B.csv
# ASDM_DIDs_pivot_201927-201939_combined_csv_row1__Buf1Pt5MplPre2_D92C.csv
# ASDM_DIDs_pivot_201927-201939_combined_csv_row1__Buf2Pt1Sng_D979.csv
# ASDM_DIDs_pivot_201927-201939_combined_csv_row1__Buf2Pt2MplPost1_D97A.csv
# ASDM_DIDs_pivot_201927-201939_combined_csv_row1__Buf2Pt3MplPost2_D97B.csv
# ASDM_DIDs_pivot_201927-201939_combined_csv_row1__Buf2Pt4MplPre1_D97C.csv
# ASDM_DIDs_pivot_201927-201939_combined_csv_row1__Buf2Pt5MplPre2_D97D.csv
# ASDM_DIDs_pivot_201927-201939_combined_csv_row1__MetaData.csv
# ASDM_DIDs_pivot_201927-201939_combined_csv_row1__Statistics_D926.csv
# ASDM_DIDs_pivot_201927-201939_combined_csv_row1__Vehicle_GlobalData.csv

# %%
a = 'ASDM_DIDs_pivot_201927-201939_combined.csv (row5699)' 
start1 = a.find('pivot_') + 6
end1 = a.find('_combined')
b = a[start1:end1]
print(b)
start2 = a.find('row') + 3
end2 = a.find(')', start2)
c = a[start2:end2]
print(c)
#########get the buffer number from the dro file!!############
# Out:
# 201927-201939
# 5699

# %%
a = 'ASDM_DIDs_pivot_201927-201939_combined_csv_row10__Buf1Pt2MplPost1_D929.csv' 
start3 = a.find('pivot_') + 6
end3 = a.find('_combined')
x = a[start3:end3]
print(b)
start4 = a.find('row') + 3
end4 = a.find('__', start4)
y = a[start4:end4]
print(c)
start5 = a.find("Buf") + 3
end5 = a.find("Pt", start5)
z = a[start5:end5]
print(d)
# Out:
# 201927-201939
# 5699
# 201927-201939row5699

# %%
list_dro = ()
for i in concatenated2:
    list_dro.append(rid, classification, BufNum)
print(list_dro)

# %%
#readout = concatenated2[concatenated2["ReadOutID"] == 'ASDM_DIDs_pivot_201701-201713_combined.csv (row0)']

# %%
#print(readout)

# %%
#len(rid)

# %%
#lst = []
#for ids in rid:
#    lst.append(ids)
#print(lst)

# %%
#len(lst)
